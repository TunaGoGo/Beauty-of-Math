# %%
import sympy as sym
import numpy as np
import math
from matplotlib import pyplot as plt

# %%
"""
牛顿-莱布尼茨公式的内容是一个连续函数在区间 [ a，b ] 上的定积分等于它的任意一个原函数在区间[ a，b ]上的增量。
假设连续函数为 y = x**2, 则他的一个原函数为 y = x**3/3
"""

# %%
x,a = sym.symbols('x a')

# %%
x = np.linspace(0,3,100)
y = x**2

# %%
plt.axis([np.min(x), np.max(x), 0, np.max(y)])
plt.plot(x,y)
plt.title("f'(x) y=x**2")
plt.fill_between(x, y1 = y, y2 = 0, where=(x>=1)&(x<=2),
                 facecolor = 'green',alpha = 0.2)
plt.show()

# %%
y_ori = sym.integrate(z**2,z)
y_ori
# Out:
# z**3/3

# %%
a = np.linspace(0,3,100)
b = a**3/3

# %%
a1 = np.linspace(1,2,100)
b1 = a1**3/3

# %%
plt.axis([np.min(a), np.max(a), 0, np.max(b)])
plt.plot(a,b)
plt.plot(a1,b1, color = 'red', linewidth = 2)
plt.title("f(x) y=x**3/3")
# plt.fill_between(a, y1 = y, y2 = 0, where=(x>=1)&(x<=2),
#                  facecolor = 'green',alpha = 0.2)
plt.show()
